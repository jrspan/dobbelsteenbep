# %%
import matplotlib.pyplot as plt

from RW_helper import *
import pandas as pd
# Out:
# Current directory successfully loaded!

# %%
df = pd.read_csv('2024-06-13_13-13-54.csv')

# %%
df.head()
# Out:
#    timestamp     x_acc     y_acc     z_acc    x_gyro    y_gyro    z_gyro  \
# 0        0.0 -0.034213 -0.005119  1.017901  0.034552  0.360576  0.759336
# 1       30.0 -0.028345 -0.001795  1.017621 -0.397972 -0.185531  0.185805
# 2       33.0 -0.028093 -0.005895  1.019951 -0.097268 -0.038752  0.065613
# 3       36.0 -0.031543 -0.008916  1.017832  0.205569 -0.310552 -0.189204
# 4       39.0 -0.031252 -0.001180  1.019604  0.090539  0.019764  0.328534
#
#    squared norm  zero velocity        px  ...        vx        vy        vz  \
# 0      0.707800          False  0.000000  ...  0.000000  0.000000  0.000000
# 1      0.227327          False  0.000398  ...  0.026534  0.000234  0.005655
# 2      0.015268          False  0.000478  ...  0.026251  0.000226  0.006253
# 3      0.174499          False  0.000556  ...  0.025832  0.000116  0.006790
# 4      0.116522          False  0.000633  ...  0.025421  0.000234  0.007378
#
# ...

# %%
fig = plt.figure(figsize=(10, 8))

plt.subplot(3, 1, 1)
plt.plot(df.loc[:, 'timestamp'] / 1000, df.loc[:, 'px'], label='x position')
plt.plot(df.loc[:, 'timestamp'] / 1000, df.loc[:, 'py'], label='y position')
plt.plot(df.loc[:, 'timestamp'] / 1000, df.loc[:, 'pz'], label='z position')
plt.title('Position Estimate')
plt.xlabel('Time (s)')
plt.ylabel('Position (m)')
plt.grid()
plt.legend()

plt.subplot(3, 1, 2)
plt.plot(df.loc[:, 'timestamp'] / 1000, df.loc[:, 'vx'], label='x velocity')
plt.plot(df.loc[:, 'timestamp'] / 1000, df.loc[:, 'vy'], label='y velocity')
plt.plot(df.loc[:, 'timestamp'] / 1000, df.loc[:, 'vz'], label='z velocity')
plt.title('Velocity Estimate')
plt.xlabel('Time (s)')
plt.ylabel('Velocity (m/s)')
plt.grid()
plt.legend()

plt.subplot(3, 1, 3)
plt.plot(df.loc[:, 'timestamp'] / 1000, df.loc[:, 'x_acc'], label='x acceleration')
plt.plot(df.loc[:, 'timestamp'] / 1000, df.loc[:, 'y_acc'], label='y acceleration')
plt.plot(df.loc[:, 'timestamp'] / 1000, df.loc[:, 'z_acc'], label='z acceleration')
plt.title('Raw Acceleration')
plt.xlabel('Time (s)')
plt.ylabel('Acceleration (g)')
plt.grid()
plt.legend()

plt.tight_layout()

plt.show()

# %%
plt.plot(df.loc[:, 'timestamp'] / 1000, df.loc[:, 'px'], label='x')
plt.plot(df.loc[:, 'timestamp'] / 1000, df.loc[:, 'py'], label='y')
plt.plot(df.loc[:, 'timestamp'] / 1000, df.loc[:, 'pz'], label='z')

plt.title('Position Estimate')
plt.xlabel('Time (s)')
plt.ylabel('Position (m)')
plt.legend()

plt.show()

# %%
figure = RW_PlotAccXYZ(df)

# %%
plt.plot(df.loc[:, 'timestamp'] / 1000, df.loc[:, 'vx'], label='x')
plt.plot(df.loc[:, 'timestamp'] / 1000, df.loc[:, 'vy'], label='y')
plt.plot(df.loc[:, 'timestamp'] / 1000, df.loc[:, 'vz'], label='z')

plt.title('Velocity Estimate')
plt.xlabel('Time (s)')
plt.ylabel('Velocity (m/s)')
plt.legend()

plt.show()

# %%
figure = RW_PlotEuler(df)

# %%
figure = RW_PlotGyrXYZ(df)
